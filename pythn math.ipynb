# %%
a=5

# %%
a
# Out:
# 5

# %%
a+5
# Out:
# 10

# %%
a+a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
isinstance(a,int)
# Out:
# True

# %%
a=5

# %%
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
b=2.8

# %%
type(b)
# Out:
# float

# %%
b=2.88888888888888888888888888888888888888888888888888888888888

# %%
b
# Out:
# 2.888888888888889

# %%
c=1+2j

# %%
type(c)
# Out:
# complex

# %%
c.conjugate()
# Out:
# (1-2j)

# %%
c.imag
# Out:
# 2.0

# %%
c.real
# Out:
# 1.0

# %%
_+2
# Out:
# 3.0

# %%
1+2
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*1
# Out:
# 2

# %%
1/1
# Out:
# 1.0

# %%
1//1
# Out:
# 1

# %%
1**2
# Out:
# 1

# %%
1.1+2.2
# Out:
# 3.3000000000000003

# %%
import decimal as d

# %%
help(d.Decimal)
# Out:
# Help on class Decimal in module decimal:
#
# class Decimal(builtins.object)
#  |  Construct a new Decimal object. 'value' can be an integer, string, tuple,
#  |  or another Decimal object. If no value is given, return Decimal('0'). The
#  |  context does not affect the conversion and is only passed to determine if
#  |  the InvalidOperation trap is active.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __ceil__(...)
#  |
#  |  __complex__(...)
#  |
#  |  __copy__(...)
#  |
#  |  __deepcopy__(...)
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(...)
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(...)
# ...

# %%
e=d.Decimal('1.1')+d.Decimal('2.2')

# %%
print(e)
# Out:
# 3.3

# %%
float(5)
# Out:
# 5.0

# %%
int(5.0)
# Out:
# 5

# %%
complex(5)
# Out:
# (5+0j)

# %%
a=complex(3.9)

# %%
a
# Out:
# (3.9+0j)

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-8b2ab3991dae> in <module>
# ----> 1 int(a)
#
# TypeError: can't convert complex to int

# %%
float(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-6c8cade3f87c> in <module>
# ----> 1 float(a)
#
# TypeError: can't convert complex to float

# %%
import math as m

# %%
m.ceil(2.000001)
# Out:
# 3

# %%
m.fabs(3.011111)
# Out:
# 3.011111

# %%
abs(-4.56666666666666)
# Out:
# 4.56666666666666

# %%
help(abs)
# Out:
# Help on built-in function abs in module builtins:
#
# abs(x, /)
#     Return the absolute value of the argument.

# %%
help(m.fabs)
# Out:
# Help on built-in function fabs in module math:
#
# fabs(...)
#     fabs(x)
#
#     Return the absolute value of the float x.

# %%
m.pow(2,3)
# Out:
# 8.0

# %%
abs(100)
# Out:
# 100

# %%
abs(100.12)
# Out:
# 100.12

# %%
m.ceil(2.01)
# Out:
# 3

# %%
m.ceil(2.9999)
# Out:
# 3

# %%
m.floor(2.9999)
# Out:
# 2

# %%
m.exp(2)
# Out:
# 7.38905609893065

# %%
m.fabs(-2.345)
# Out:
# 2.345

# %%
m.factorial(2)
# Out:
# 2

# %%
m.factorial(5)
# Out:
# 120

# %%
m.log(2)
# Out:
# 0.6931471805599453

# %%
m.log10(2)
# Out:
# 0.3010299956639812

# %%
m.log10(10)
# Out:
# 1.0

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %%
max(1,2,3)
# Out:
# 3

# %%
min(1,2,3)
# Out:
# 1

# %%
m.modf(100.12)
# Out:
# (0.12000000000000455, 100.0)

# %%
m.pow(2,2)
# Out:
# 4.0

# %%
round(1.2222222222222222)
# Out:
# 1

# %%
round(1.22222222222,100)
# Out:
# 1.22222222222

# %%
m.sqrt(25)
# Out:
# 5.0

# %%
import math as ma

# %%
abs(2.3)
# Out:
# 2.3

# %%
abs(-2.333)
# Out:
# 2.333

# %%
a=10

# %%
a=10,10

# %%
a
# Out:
# (10, 10)

# %%
a=1

# %%
a,b='arun','kumar'

# %%
b
# Out:
# 'kumar'

# %%
x,y=3,5

# %%
y
# Out:
# 5

# %%
a,b=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-0221c3fad332> in <module>
# ----> 1 a,b=10
#
# TypeError: 'int' object is not iterable

# %%
a,b=10,11

# %%
b
# Out:
# 11

# %%
import math as m

# %%
abs(1-10.2)
# Out:
# 9.2

# %%
abs(10.2-1)
# Out:
# 9.2

# %%
m.ceil(1.00000000000001)
# Out:
# 2

# %%
m.floor(1.999999)
# Out:
# 1

# %%
complex(1,2)
# Out:
# (1+2j)

# %%
m.fabs(-1.23)
# Out:
# 1.23

# %%
m.log(1.2)
# Out:
# 0.1823215567939546

# %%
m.log10(10)
# Out:
# 1.0

# %%
m.exp(2)
# Out:
# 7.38905609893065

# %%
max(1,1,2,3,4,5,6)
# Out:
# 6

# %%
min(1,1,0,10,1)
# Out:
# 0

# %%
m.modf(1.08)
# Out:
# (0.08000000000000007, 1.0)

# %%
round(1.222222222222,1)
# Out:
# 1.2

# %%
m.sqrt(25)
# Out:
# 5.0

# %% [raw]
# 1)abs
# 2)ceil
# 3)floor
# 4)fabs
# 5)complex
# 6)exp
# 7)log
# 8)log10
# 9)max
# 10)min
# 11)pow
# 12)round
# 13)sqrt

# %% [raw]
# _(under score is used to store the previous output in python)

# %%
a=10

# %%
_+12
# Out:
# 17.0

# %%
a
# Out:
# 10

# %%
_+5
# Out:
# 15

# %%
b=13

# %%
_+14
# Out:
# 29

# %%
b
# Out:
# 13

# %%
_+14
# Out:
# 27

# %% [markdown]
# # Random

# %%
import random as r

# %%
r.choice([1,2,3,4])
# Out:
# 1

# %%
r.randrange(2,10,2)
# Out:
# 8

# %%
r.random()
# Out:
# 0.6490329101535663

# %%
r.randint(1,80)
# Out:
# 72

# %%
r.seed(10)

# %%
r.randint(2,12)
# Out:
# 11

# %%
r.uniform(2,4)
# Out:
# 2.9651233491017117

# %%
r.choice([2,3,4])
# Out:
# 2

# %%
r.randint(10,100)
# Out:
# 69

# %%
r.Random(1)

# %%
r.random()
# Out:
# 0.81332125135732

# %%
r.randrange(2,100,2)
# Out:
# 36

# %%
r.seed(100)

# %%
r.randrange(2,120,2)
# Out:
# 20

# %%
a=r.shuffle([1,2,3,4,5])

# %%
print(a)
# Out:
# None

# %%
l=[1,2,3,4]

# %%
r.shuffle(l)

# %%
l
# Out:
# [2, 1, 3, 4]

# %%
l
# Out:
# [2, 1, 3, 4]

# %%
r.uniform(2,3)
# Out:
# 2.33535077594001

# %%
help(r.uniform)
# Out:
# Help on method uniform in module random:
#
# uniform(a, b) method of random.Random instance
#     Get a random number in the range [a, b) or [a, b] depending on rounding.

# %%
m.sin(60)
# Out:
# -0.3048106211022167

# %%
m.cos(100)
# Out:
# 0.8623188722876839

# %%
m.cos(60)
# Out:
# -0.9524129804151563

# %%
m.sinh(60)
# Out:
# 5.710036949078421e+25

# %%
m.pi(60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-218-272d09a8c2eb> in <module>
# ----> 1 m.pi(60)
#
# TypeError: 'float' object is not callable

# %%
m.degrees(60)
# Out:
# 3437.746770784939

# %%
m.radians(60)
# Out:
# 1.0471975511965976

# %%
m.pi
# Out:
# 3.141592653589793

# %%
m.sin(m.pi)
# Out:
# 1.2246467991473532e-16

# %%
m.cos(m.pi)
# Out:
# -1.0

# %%
m.cos(60)
# Out:
# -0.9524129804151563

# %%
import math as m

# %%
abs(-100.12345)
# Out:
# 100.12345

# %%
m.ceil(2.0000000001)
# Out:
# 3

# %%
complex(3,5)
# Out:
# (3+5j)

# %%
m.floor(2.00000000001)
# Out:
# 2

# %%
m.fabs(8.10001)
# Out:
# 8.10001

# %%
m.factorial(9)
# Out:
# 362880
